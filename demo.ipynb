# %%
import sys
import argparse
import yaml
import numpy

import cv2
import torch
from torch.autograd import Variable

from models.yolov3 import *
from utils.utils import *
from utils.parse_yolo_weights import parse_yolo_weights
from utils.vis_bbox import vis_bbox

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Choose config file for this demo
cfg_path = '/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/config/gaussian_yolov3_eval.cfg'

# Specify checkpoint file which contains the weight of the model you want to use
ckpt_path = '/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/gaussian_yolov3_coco.pth'

# Path to the image file fo the demo
image_path = '/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/data/gaussian_yolov3/traffic_1.jpg'

# Detection threshold
detect_thresh = 0.3

# Use CPU if gpu < 0 else use GPU
gpu = -1

# %%
# Load configratio parameters for this demo
with open(cfg_path, 'r') as f:
    cfg = yaml.load(f)

model_config = cfg['MODEL']
imgsize = cfg['TEST']['IMGSIZE']
confthre = cfg['TEST']['CONFTHRE'] 
nmsthre = cfg['TEST']['NMSTHRE']
gaussian = cfg['MODEL']['GAUSSIAN']

# if detect_thresh is not specified, the parameter defined in config file is used
if detect_thresh:
    confthre = detect_thresh
# Out:
# /tmp/ipykernel_3639/4136682909.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(f)

# %%
import torch, torchvision.models
# Load model
model = YOLOv3(model_config)

# Load weight from the checkpoint
print("loading checkpoint %s" % (ckpt_path))
state = torch.load(ckpt_path)

if 'model_state_dict' in state.keys():
    model.load_state_dict(state['model_state_dict'])
else:
    model.load_state_dict(state)

model.eval()

if gpu >= 0:
    # Send model to GPU
    model.cuda()
# Out:
# Gaussian YOLOv3
# Gaussian YOLOv3
# Gaussian YOLOv3
# loading checkpoint /home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/gaussian_yolov3_coco.pth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb Cell 4 in <cell line: 9>()
#      <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=9'>10</a>     model.load_state_dict(state['model_state_dict'])
#      <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=10'>11</a> else:
# ---> <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=11'>12</a>     model.load_state_dict(state)
#      <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=13'>14</a> model.eval()
#      <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=15'>16</a> if gpu >= 0:
#      <a href='vscode-notebook-cell:/home/samsung/Downloads/PyTorch_Gaussian_YOLOv3-master/demo.ipynb#ch0000003?line=16'>17</a>     # Send model to GPU
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1604, in Module.load_state_dict(self, state_dict, strict)
#    1599         error_msgs.insert(
#    1600             0, 'Missing key(s) in state_dict: {}. '.format(
#    1601                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1603 if len(error_msgs) > 0:
# -> 1604     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1605                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1606 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for YOLOv3:
# 	Missing key(s) in state_dict: "module_list.2.conv.weight", "module_list.2.batch_norm.weight", "module_list.2.batch_norm.bias", "module_list.2.batch_norm.running_mean", "module_list.2.batch_norm.running_var", "module_list.4.module_list.2.0.conv.weight", "module_list.4.module_list.2.0.batch_norm.weight", "module_list.4.module_list.2.0.batch_norm.bias", "module_list.4.module_list.2.0.batch_norm.running_mean", "module_list.4.module_list.2.0.batch_norm.running_var", "module_list.4.module_list.2.1.conv.weight", "module_list.4.module_list.2.1.batch_norm.weight", "module_list.4.module_list.2.1.batch_norm.bias", "module_list.4.module_list.2.1.batch_norm.running_mean", "module_list.4.module_list.2.1.batch_norm.running_var", "module_list.6.conv.weight", "module_list.6.batch_norm.weight", "module_list.6.batch_norm.bias", "module_list.6.batch_norm.running_mean", "module_list.6.batch_norm.running_var", "module_list.10.conv.weight", "module_list.10.batch_norm.weight", "module_list.10.batch_norm.bias", "module_list.10.batch_norm.running_mean", "module_list.10.batch_norm.running_var", "module_list.11.conv.weight", "module_list.11.batch_norm.weight", "module_list.11.batch_norm.bias", "module_list.11.batch_norm.running_mean", "module_list.11.batch_norm.running_var", "module_list.12.module_list.0.0.conv.weight", "module_list.12.module_list.0.0.batch_norm.weight", "module_list.12.module_list.0.0.batch_norm.bias", "module_list.12.module_list.0.0.batch_norm.running_mean", "module_list.12.module_list.0.0.batch_norm.running_var", "module_list.12.module_list.0.1.conv.weight", "module_list.12.module_list.0.1.batch_norm.weight", "module_list.12.module_list.0.1.batch_norm.bias", "module_list.12.module_list.0.1.batch_norm.running_mean", "module_list.12.module_list.0.1.batch_norm.running_var", "module_list.12.module_list.1.0.conv.weight", "module_list.12.module_list.1.0.batch_norm.weight", "module_list.12.module_list.1.0.batch_norm.bias", "module_list.12.module_list.1.0.batch_norm.running_mean", "module_list.12.module_list.1.0.batch_norm.running_var", "module_list.12.module_list.1.1.conv.weight", "module_list.12.module_list.1.1.batch_norm.weight", "module_list.12.module_list.1.1.batch_norm.bias", "module_list.12.module_list.1.1.batch_norm.running_mean", "module_list.12.module_list.1.1.batch_norm.running_var", "module_list.12.module_list.2.0.conv.weight", "module_list.12.module_list.2.0.batch_norm.weight", "module_list.12.module_list.2.0.batch_norm.bias", "module_list.12.module_list.2.0.batch_norm.running_mean", "module_list.12.module_list.2.0.batch_norm.running_var", "module_list.12.module_list.2.1.conv.weight", "module_list.12.module_list.2.1.batch_norm.weight", "module_list.12.module_list.2.1.batch_norm.bias", "module_list.12.module_list.2.1.batch_norm.running_mean", "module_list.12.module_list.2.1.batch_norm.running_var", "module_list.12.module_list.3.0.conv.weight", "module_list.12.module_list.3.0.batch_norm.weight", "module_list.12.module_list.3.0.batch_norm.bias", "module_list.12.module_list.3.0.batch_norm.running_mean", "module_list.12.module_list.3.0.batch_norm.running_var", "module_list.12.module_list.3.1.conv.weight", "module_list.12.module_list.3.1.batch_norm.weight", "module_list.12.module_list.3.1.batch_norm.bias", "module_list.12.module_list.3.1.batch_norm.running_mean", "module_list.12.module_list.3.1.batch_norm.running_var", "module_list.12.module_list.4.0.conv.weight", "module_list.12.module_list.4.0.batch_norm.weight", "module_list.12.module_list.4.0.batch_norm.bias", "module_list.12.module_list.4.0.batch_norm.running_mean", "module_list.12.module_list.4.0.batch_norm.running_var", "module_list.12.module_list.4.1.conv.weight", "module_list.12.module_list.4.1.batch_norm.weight", "module_list.12.module_list.4.1.batch_norm.bias", "module_list.12.module_list.4.1.batch_norm.running_mean", "module_list.12.module_list.4.1.batch_norm.running_var", "module_list.12.module_list.5.0.conv.weight", "module_list.12.module_list.5.0.batch_norm.weight", "mo ...
# 	Unexpected key(s) in state_dict: "module_list.2.module_list.0.0.conv.weight", "module_list.2.module_list.0.0.batch_norm.weight", "module_list.2.module_list.0.0.batch_norm.bias", "module_list.2.module_list.0.0.batch_norm.running_mean", "module_list.2.module_list.0.0.batch_norm.running_var", "module_list.2.module_list.0.0.batch_norm.num_batches_tracked", "module_list.2.module_list.0.1.conv.weight", "module_list.2.module_list.0.1.batch_norm.weight", "module_list.2.module_list.0.1.batch_norm.bias", "module_list.2.module_list.0.1.batch_norm.running_mean", "module_list.2.module_list.0.1.batch_norm.running_var", "module_list.2.module_list.0.1.batch_norm.num_batches_tracked", "module_list.6.module_list.0.0.conv.weight", "module_list.6.module_list.0.0.batch_norm.weight", "module_list.6.module_list.0.0.batch_norm.bias", "module_list.6.module_list.0.0.batch_norm.running_mean", "module_list.6.module_list.0.0.batch_norm.running_var", "module_list.6.module_list.0.0.batch_norm.num_batches_tracked", "module_list.6.module_list.0.1.conv.weight", "module_list.6.module_list.0.1.batch_norm.weight", "module_list.6.module_list.0.1.batch_norm.bias", "module_list.6.module_list.0.1.batch_norm.running_mean", "module_list.6.module_list.0.1.batch_norm.running_var", "module_list.6.module_list.0.1.batch_norm.num_batches_tracked", "module_list.6.module_list.1.0.conv.weight", "module_list.6.module_list.1.0.batch_norm.weight", "module_list.6.module_list.1.0.batch_norm.bias", "module_list.6.module_list.1.0.batch_norm.running_mean", "module_list.6.module_list.1.0.batch_norm.running_var", "module_list.6.module_list.1.0.batch_norm.num_batches_tracked", "module_list.6.module_list.1.1.conv.weight", "module_list.6.module_list.1.1.batch_norm.weight", "module_list.6.module_list.1.1.batch_norm.bias", "module_list.6.module_list.1.1.batch_norm.running_mean", "module_list.6.module_list.1.1.batch_norm.running_var", "module_list.6.module_list.1.1.batch_norm.num_batches_tracked", "module_list.6.module_list.2.0.conv.weight", "module_list.6.module_list.2.0.batch_norm.weight", "module_list.6.module_list.2.0.batch_norm.bias", "module_list.6.module_list.2.0.batch_norm.running_mean", "module_list.6.module_list.2.0.batch_norm.running_var", "module_list.6.module_list.2.0.batch_norm.num_batches_tracked", "module_list.6.module_list.2.1.conv.weight", "module_list.6.module_list.2.1.batch_norm.weight", "module_list.6.module_list.2.1.batch_norm.bias", "module_list.6.module_list.2.1.batch_norm.running_mean", "module_list.6.module_list.2.1.batch_norm.running_var", "module_list.6.module_list.2.1.batch_norm.num_batches_tracked", "module_list.6.module_list.3.0.conv.weight", "module_list.6.module_list.3.0.batch_norm.weight", "module_list.6.module_list.3.0.batch_norm.bias", "module_list.6.module_list.3.0.batch_norm.running_mean", "module_list.6.module_list.3.0.batch_norm.running_var", "module_list.6.module_list.3.0.batch_norm.num_batches_tracked", "module_list.6.module_list.3.1.conv.weight", "module_list.6.module_list.3.1.batch_norm.weight", "module_list.6.module_list.3.1.batch_norm.bias", "module_list.6.module_list.3.1.batch_norm.running_mean", "module_list.6.module_list.3.1.batch_norm.running_var", "module_list.6.module_list.3.1.batch_norm.num_batches_tracked", "module_list.6.module_list.4.0.conv.weight", "module_list.6.module_list.4.0.batch_norm.weight", "module_list.6.module_list.4.0.batch_norm.bias", "module_list.6.module_list.4.0.batch_norm.running_mean", "module_list.6.module_list.4.0.batch_norm.running_var", "module_list.6.module_list.4.0.batch_norm.num_batches_tracked", "module_list.6.module_list.4.1.conv.weight", "module_list.6.module_list.4.1.batch_norm.weight", "module_list.6.module_list.4.1.batch_norm.bias", "module_list.6.module_list.4.1.batch_norm.running_mean", "module_list.6.module_list.4.1.batch_norm.running_var", "module_list.6.module_list.4.1.batch_norm.num_batches_tracked", "module_list.6.module_list.5.0.conv.weight", "module_list.6.module_list.5.0.batch_norm.weight", "modul ...
# 	size mismatch for module_list.0.conv.weight: copying a param with shape torch.Size([32, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 3, 7, 7]).
# 	size mismatch for module_list.0.batch_norm.weight: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module_list.0.batch_norm.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module_list.0.batch_norm.running_mean: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module_list.0.batch_norm.running_var: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for module_list.1.conv.weight: copying a param with shape torch.Size([64, 32, 3, 3]) from checkpoint, the shape in current model is torch.Size([64, 64, 1, 1]).
# 	size mismatch for module_list.3.conv.weight: copying a param with shape torch.Size([128, 64, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 64, 1, 1]).
# 	size mismatch for module_list.3.batch_norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.3.batch_norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.3.batch_norm.running_mean: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.3.batch_norm.running_var: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.0.0.conv.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for module_list.4.module_list.0.0.batch_norm.weight: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.0.0.batch_norm.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.0.0.batch_norm.running_mean: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.0.0.batch_norm.running_var: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.0.1.conv.weight: copying a param with shape torch.Size([128, 64, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 128, 3, 3]).
# 	size mismatch for module_list.4.module_list.0.1.batch_norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.0.1.batch_norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.0.1.batch_norm.running_mean: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.0.1.batch_norm.running_var: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.1.0.conv.weight: copying a param with shape torch.Size([64, 128, 1, 1]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for module_list.4.module_list.1.0.batch_norm.weight: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.1.0.batch_norm.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.1.0.batch_norm.running_mean: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.1.0.batch_norm.running_var: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.4.module_list.1.1.conv.weight: copying a param with shape torch.Size([128, 64, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 128, 3, 3]).
# 	size mismatch for module_list.4.module_list.1.1.batch_norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.1.1.batch_norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.1.1.batch_norm.running_mean: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.4.module_list.1.1.batch_norm.running_var: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.5.conv.weight: copying a param with shape torch.Size([256, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([128, 256, 1, 1]).
# 	size mismatch for module_list.5.batch_norm.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.5.batch_norm.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.5.batch_norm.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.5.batch_norm.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for module_list.7.conv.weight: copying a param with shape torch.Size([512, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 128, 1, 1]).
# 	size mismatch for module_list.9.conv.weight: copying a param with shape torch.Size([1024, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 512, 1, 1]).
# 	size mismatch for module_list.9.batch_norm.weight: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.9.batch_norm.bias: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.9.batch_norm.running_mean: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.9.batch_norm.running_var: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.13.conv.weight: copying a param with shape torch.Size([1024, 512, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 1024, 1, 1]).
# 	size mismatch for module_list.13.batch_norm.weight: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for module_list.13.batch_norm.bias: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for module_list.13.batch_norm.running_mean: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for module_list.13.batch_norm.running_var: copying a param with shape torch.Size([1024]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for module_list.14.conv.weight: copying a param with shape torch.Size([267, 1024, 1, 1]) from checkpoint, the shape in current model is torch.Size([512, 512, 3, 3]).
# 	size mismatch for module_list.15.conv.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([2048, 512, 1, 1]).
# 	size mismatch for module_list.15.batch_norm.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for module_list.15.batch_norm.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for module_list.15.batch_norm.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for module_list.15.batch_norm.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([2048]).
# 	size mismatch for module_list.18.conv.weight: copying a param with shape torch.Size([512, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([512, 1024, 1, 1]).
# 	size mismatch for module_list.20.conv.weight: copying a param with shape torch.Size([256, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([267, 1024, 1, 1]).
# 	size mismatch for module_list.21.conv.weight: copying a param with shape torch.Size([512, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 512, 1, 1]).
# 	size mismatch for module_list.21.batch_norm.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.21.batch_norm.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.21.batch_norm.running_mean: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.21.batch_norm.running_var: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.23.conv.weight: copying a param with shape torch.Size([128, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([256, 768, 1, 1]).
# 	size mismatch for module_list.23.batch_norm.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.23.batch_norm.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.23.batch_norm.running_mean: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.23.batch_norm.running_var: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for module_list.26.conv.weight: copying a param with shape torch.Size([256, 128, 3, 3]) from checkpoint, the shape in current model is torch.Size([256, 512, 1, 1]).
# 	size mismatch for module_list.28.conv.weight: copying a param with shape torch.Size([267, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([267, 512, 1, 1]).

# %%
# Load image
img = cv2.imread(image_path)

# Preprocess image
img_raw = img.copy()[:, :, ::-1].transpose((2, 0, 1))
img, info_img = preprocess(img, imgsize, jitter=0)  # info = (h, w, nh, nw, dx, dy)
img = np.transpose(img / 255., (2, 0, 1))
img = torch.from_numpy(img).float().unsqueeze(0)

if gpu >= 0:
    # Send model to GPU
    img = Variable(img.type(torch.cuda.FloatTensor))
else:
    img = Variable(img.type(torch.FloatTensor))

# %%
# Inference
with torch.no_grad():
    outputs = model(img)
    outputs = postprocess(outputs, 80, confthre, nmsthre)

if outputs[0] is None:
    print("No Objects Deteted!!")
    sys.exit(0)

# Visualize detected bboxes
coco_class_names, coco_class_ids, coco_class_colors = get_coco_label_names()

bboxes = list()
classes = list()
scores = list()
colors = list()
sigmas = list()

for output in outputs[0]:
    x1, y1, x2, y2, conf, cls_conf, cls_pred = output[:7]
    if gaussian:
        sigma_x, sigma_y, sigma_w, sigma_h = output[7:]
        sigmas.append([sigma_x, sigma_y, sigma_w, sigma_h])

    cls_id = coco_class_ids[int(cls_pred)]
    box = yolobox2label([y1, x1, y2, x2], info_img)
    bboxes.append(box)
    classes.append(cls_id)
    scores.append(cls_conf * conf)
    colors.append(coco_class_colors[int(cls_pred)])
    
    # image size scale used for sigma visualization
    h, w, nh, nw, _, _ = info_img
    sigma_scale_img = (w / nw, h / nh)
    
fig, ax = vis_bbox(
    img_raw, bboxes, label=classes, score=scores, label_names=coco_class_names, sigma=sigmas, 
    sigma_scale_img=sigma_scale_img,
    sigma_scale_xy=2., sigma_scale_wh=2.,  # 2-sigma
    show_inner_bound=False,  # do not show inner rectangle for simplicity
    instance_colors=colors, linewidth=3)

fig.savefig('trailRun.png')
